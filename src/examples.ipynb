# %%
# %load_ext cypher

# %%
# %config CypherMagic
# Out:
# CypherMagic options
# -----------------
# CypherMagic.auto_html=<Bool>
#     Current: False
#     Return a D3 representation of the graph instead of regular result sets
# CypherMagic.auto_limit=<Int>
#     Current: 0
#     Automatically limit the size of the returned result sets
# CypherMagic.auto_networkx=<Bool>
#     Current: False
#     Return Networkx MultiDiGraph instead of regular result sets
# CypherMagic.auto_pandas=<Bool>
#     Current: False
#     Return Pandas DataFrame instead of regular result sets
# CypherMagic.data_contents=<Bool>
#     Current: True
#     Bring extra data to render the results as a graph
# CypherMagic.display_limit=<Int>
#     Current: 0
#     Automatically limit the number of rows displayed (full result set is still
#     stored)
# CypherMagic.feedback=<Bool>
#     Current: True
#     Print number of rows affected
# CypherMagic.rest=<Bool>
#     Current: False
#     Return full REST representations of objects inside the result sets
# CypherMagic.short_errors=<Bool>
#     Current: True
#     Don't display the full traceback on Neo4j errors
# CypherMagic.style=<Unicode>
#     Current: u'DEFAULT'
#     Set the table printing style to any of prettytable's defined styles
#     (currently DEFAULT, MSWORD_FRIENDLY, PLAIN_COLUMNS, RANDOM)

# %%
# %cypher match (n)-[r]-() delete n, r
# Out:
# 6 relationship deleted.
# 6 nodes deleted.
# []

# %%
# %%cypher
# create
#     // Nodes
#     (Neo:Crew {name:'Neo'}),
#     (Morpheus:Crew {name: 'Morpheus'}),
#     (Trinity:Crew {name: 'Trinity'}),
#     (Cypher:Crew:Matrix {name: 'Cypher'}),
#     (Smith:Matrix {name: 'Agent Smith'}),
#     (Architect:Matrix {name:'The Architect'}),
#     // Relationships
#     (Neo)-[:KNOWS]->(Morpheus),
#     (Neo)-[:LOVES]->(Trinity),
#     (Morpheus)-[:KNOWS]->(Trinity),
#     (Morpheus)-[:KNOWS]->(Cypher),
#     (Cypher)-[:KNOWS]->(Smith),
#     (Smith)-[:CODED_BY]->(Architect);
# Out:
# 7 labels added.
# 6 nodes created.
# 6 properties set.
# 6 relationships created.
# []

# %%
# %cypher match (n)-[r]-() return n, count(r) as degree order by degree desc
# Out:
# 6 rows affected.
# [[{u'name': u'Morpheus'}, 3],
#  [{u'name': u'Neo'}, 2],
#  [{u'name': u'Cypher'}, 2],
#  [{u'name': u'Trinity'}, 2],
#  [{u'name': u'Agent Smith'}, 2],
#  [{u'name': u'The Architect'}, 1]]

# %%
results = %cypher match (n)-[r]-() return n.name as name, n, r, count(r) as degree order by degree desc
# Out:
# 12 rows affected.

# %%
# %matplotlib inline

# %%
results.dataframe()
# Out:
#              name                            n   r  degree
# 0          Cypher         {u'name': u'Cypher'}  {}       1
# 1     Agent Smith    {u'name': u'Agent Smith'}  {}       1
# 2   The Architect  {u'name': u'The Architect'}  {}       1
# 3        Morpheus       {u'name': u'Morpheus'}  {}       1
# 4          Cypher         {u'name': u'Cypher'}  {}       1
# 5         Trinity        {u'name': u'Trinity'}  {}       1
# 6             Neo            {u'name': u'Neo'}  {}       1
# 7         Trinity        {u'name': u'Trinity'}  {}       1
# 8     Agent Smith    {u'name': u'Agent Smith'}  {}       1
# 9        Morpheus       {u'name': u'Morpheus'}  {}       1
# 10            Neo            {u'name': u'Neo'}  {}       1
# 11       Morpheus       {u'name': u'Morpheus'}  {}       1

# %%
results.plot()

# %%
results.bar()
# Out:
# <Container object of 12 artists>

# %%
results.pie()
# Out:
# ([<matplotlib.patches.Wedge at 0x7fd01cf9bb50>,
#   <matplotlib.patches.Wedge at 0x7fd01cf28590>,
#   <matplotlib.patches.Wedge at 0x7fd01cf28f10>,
#   <matplotlib.patches.Wedge at 0x7fd01cf368d0>,
#   <matplotlib.patches.Wedge at 0x7fd01cf43290>,
#   <matplotlib.patches.Wedge at 0x7fd01cf43c10>,
#   <matplotlib.patches.Wedge at 0x7fd01cf4e5d0>,
#   <matplotlib.patches.Wedge at 0x7fd01cf4ef50>,
#   <matplotlib.patches.Wedge at 0x7fd01cf5d910>,
#   <matplotlib.patches.Wedge at 0x7fd01cee82d0>,
#   <matplotlib.patches.Wedge at 0x7fd01cee8c50>,
#   <matplotlib.patches.Wedge at 0x7fd01cef5610>],
#  [<matplotlib.text.Text at 0x7fd01cf28150>,
#   <matplotlib.text.Text at 0x7fd01cf28b50>,
#   <matplotlib.text.Text at 0x7fd01cf36510>,
#   <matplotlib.text.Text at 0x7fd01cf36e90>,
#   <matplotlib.text.Text at 0x7fd01cf43850>,
#   <matplotlib.text.Text at 0x7fd01cf4e210>,
#   <matplotlib.text.Text at 0x7fd01cf4eb90>,
#   <matplotlib.text.Text at 0x7fd01cf5d550>,
#   <matplotlib.text.Text at 0x7fd01cf5ded0>,
#   <matplotlib.text.Text at 0x7fd01cee8890>,
#   <matplotlib.text.Text at 0x7fd01cef5250>,
#   <matplotlib.text.Text at 0x7fd01cef5bd0>])

# %%
for i in range(1, 5):
    # %cypher match (n) return n, n.name limit {i}
# Out:
# 1 rows affected.
# 2 rows affected.
# 3 rows affected.
# 4 rows affected.

# %%
results.draw()
# Out:
# /home/versae/.venvs/ipython-cypher/local/lib/python2.7/site-packages/matplotlib/text.py:52: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if rotation in ('horizontal', None):
# /home/versae/.venvs/ipython-cypher/local/lib/python2.7/site-packages/matplotlib/text.py:54: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   elif rotation == 'vertical':
